# %%
from functions import get_chat_history, invoke_Agent, delete_chat

response = get_chat_history()
# Out:
# Dialect: mysql
# Tables: ['2017_budgets', 'customers', 'products', 'regions', 'sales_order', 'sales_orders_old', 'state_regions']

# %%
config = {
    'configurable': {
        'thread_id': 'user_3'
    }
}
response = delete_chat(config)
# Out:
# user_3
# user_3
# Thread 'user_3' deleted successfully.

# %%
response
# Out:
# {'threads': {'user_1': [{'role': 'user',
#     'content': 'What was the total education budget in 2017?'},
#    {'role': 'assistant',
#     'content': 'The database only contains a table called **2017_budgets**, which lists budget amounts for various products. Summing all of those amounts gives a total of **62,700,262.34** (in the units used by the table).  \n\nIf you were looking for a specific “education” budget, that information isn’t present in the current schema.'},
#    {'role': 'user',
#     'content': 'What was the total sales amount in the first month of sales_orders_old?'},
#    {'role': 'assistant',
#     'content': 'The total sales amount for the first month recorded in the\u202f`sales_orders_old`\u202ftable (January\u202f2014) is **$25,020,272.30**.'},
#    {'role': 'user', 'content': 'What was the total education budget in 2017?'},
#    {'role': 'assistant',
# ...

# %%
config = {
    'configurable': {
        'thread_id': 'user_2'
    }
}
response = invoke_Agent(config, 'what is the total number of products')

# %%
print(response)
# Out:
# message sent succesfully
